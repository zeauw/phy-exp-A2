# %% [markdown]
# 共振频率约$90.8Hz$
# $\tau_max=2.75\mu s$，时间间隔$0.27\mu s$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

r = 3.2602
data = pd.read_csv('data.csv')
f = data['f']
g = (data['U1']/(data['U']*r))*np.cos(2*np.pi*data['tau']*0.001*data['f'])

fig, ax = plt.subplots()
ax.scatter(f, g)
ax.plot(f, g, '--')

# %% [markdown]
# $f_1=90.61kHz$,$f_2=91.06kHz$,$D=81.862mS$,$\hat{AC}=0.321mS$
#
# - $R_1=8.955\Omega$
# - $L_1=4.320 mS$
# - $C_1=710.6pF$
# - $C_0=767.2pF$
# - $Qm=43.82$
